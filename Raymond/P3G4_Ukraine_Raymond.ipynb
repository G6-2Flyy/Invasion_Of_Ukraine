# %%
import matplotlib.pyplot as plt
import pandas as pd
import scipy.stats as st
import numpy as np
import json

# %%
data = pd.read_csv("./Resources/2022-01-01-2023-01-17-Europe-Ukraine.csv")
data.head(10)
# Out:
#    data_id  iso event_id_cnty  event_id_no_cnty       event_date  year  \
# 0  9778529  804      UKR87293             87293  13 January 2023  2023
# 1  9778529  804      UKR87293             87293  13 January 2023  2023
# 2  9778632  804      UKR87396             87396  13 January 2023  2023
# 3  9778632  804      UKR87396             87396  13 January 2023  2023
# 4  9778633  804      UKR87397             87397  13 January 2023  2023
# 5  9778633  804      UKR87397             87397  13 January 2023  2023
# 6  9778634  804      UKR87398             87398  13 January 2023  2023
# 7  9778634  804      UKR87398             87398  13 January 2023  2023
# 8  9778635  804      UKR87399             87399  13 January 2023  2023
# 9  9778635  804      UKR87399             87399  13 January 2023  2023
#
#    time_precision event_type sub_event_type  \
# 0               1    Battles    Armed clash
# 1               1    Battles    Armed clash
# 2               1    Battles    Armed clash
# ...

# %%
data.columns
# Out:
# Index(['data_id', 'iso', 'event_id_cnty', 'event_id_no_cnty', 'event_date',
#        'year', 'time_precision', 'event_type', 'sub_event_type', 'actor1',
#        'assoc_actor_1', 'inter1', 'interaction', 'region', 'country', 'admin1',
#        'admin2', 'admin3', 'location', 'latitude', 'longitude',
#        'geo_precision', 'source', 'source_scale', 'notes', 'fatalities',
#        'timestamp', 'iso3'],
#       dtype='object')

# %%
df1.drop_duplicates().info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 54821 entries, 0 to 54836
# Data columns (total 18 columns):
#  #   Column          Non-Null Count  Dtype
# ---  ------          --------------  -----
#  0   data_id         54821 non-null  int64
#  1   event_date      54821 non-null  object
#  2   year            54821 non-null  int64
#  3   event_type      54821 non-null  object
#  4   sub_event_type  54821 non-null  object
#  5   actor1          54821 non-null  object
#  6   interaction     54821 non-null  int64
#  7   admin1          54805 non-null  object
#  8   admin2          54723 non-null  object
#  9   admin3          54342 non-null  object
#  10  location        54821 non-null  object
#  11  latitude        54821 non-null  float64
#  12  longitude       54821 non-null  float64
#  13  source          54821 non-null  object
#  14  notes           54821 non-null  object
#  15  fatalities      54821 non-null  int64
#  16  timestamp       54821 non-null  int64
# ...

# %%
df1 = data.drop(columns =['iso', 'event_id_cnty', 'event_id_no_cnty' , 'time_precision', 'assoc_actor_1', 'inter1', 'region',  'country',  'geo_precision', 'source_scale'])
df1_rand = df1.sample(n=1000, random_state=1000)
df1_rand.head()
# Out:
#        data_id        event_date  year                  event_type  \
# 29781  9439679      31 July 2022  2022  Explosions/Remote violence
# 15190  9579592   13 October 2022  2022  Explosions/Remote violence
# 5197   9709984  09 December 2022  2022  Explosions/Remote violence
# 15108  9579009   13 October 2022  2022  Explosions/Remote violence
# 17092  9561869   03 October 2022  2022                     Battles
#
#                           sub_event_type                              actor1  \
# 29781  Shelling/artillery/missile attack   Military Forces of Russia (2000-)
# 15190  Shelling/artillery/missile attack   Military Forces of Russia (2000-)
# 5197   Shelling/artillery/missile attack  Military Forces of Ukraine (2019-)
# 15108                   Air/drone strike   Military Forces of Russia (2000-)
# 17092                        Armed clash  Military Forces of Ukraine (2019-)
#
#        interaction    admin1       admin2               admin3  \
# ...

# %%
# storing the data in JSON format
df1_rand.to_json('./resources/file.json', orient = 'records')

# %%
print(d)
# Out:
#        data_id         event_date  year                  event_type  \
# 29781  9439679       31 July 2022  2022  Explosions/Remote violence
# 15190  9579592    13 October 2022  2022  Explosions/Remote violence
# 5197   9709984   09 December 2022  2022  Explosions/Remote violence
# 15108  9579009    13 October 2022  2022  Explosions/Remote violence
# 17092  9561869    03 October 2022  2022                     Battles
# ...        ...                ...   ...                         ...
# 13662  9605096    22 October 2022  2022                     Battles
# 19285  9503640  21 September 2022  2022  Explosions/Remote violence
# 30003  9457309       30 July 2022  2022      Strategic developments
# 53720  8853944   14 February 2022  2022  Explosions/Remote violence
# 47288  8983078      31 March 2022  2022  Explosions/Remote violence
#
#                           sub_event_type  \
# 29781  Shelling/artillery/missile attack
# 15190  Shelling/artillery/missile attack
# ...

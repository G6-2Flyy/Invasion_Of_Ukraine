# %%
import pandas as pd
import json
import matplotlib.pyplot as plt
import numpy as np

# %%
file = "../data/2022-01-01-2023-01-17-Europe-Ukraine.csv"
df = pd.read_csv(file)

# %%
df.head()
# Out:
#    data_id  iso event_id_cnty  event_id_no_cnty event_date  year  \
# 0  9778529  804      UKR87293             87293  13-Jan-23  2023
# 1  9778529  804      UKR87293             87293  13-Jan-23  2023
# 2  9778632  804      UKR87396             87396  13-Jan-23  2023
# 3  9778632  804      UKR87396             87396  13-Jan-23  2023
# 4  9778633  804      UKR87397             87397  13-Jan-23  2023
#
#    time_precision event_type sub_event_type  \
# 0               1    Battles    Armed clash
# 1               1    Battles    Armed clash
# 2               1    Battles    Armed clash
# 3               1    Battles    Armed clash
# 4               1    Battles    Armed clash
#
#                                actor1  ...     location  latitude  longitude  \
# 0   Military Forces of Russia (2000-)  ...      Soledar   48.6969    38.0611
# 1  Military Forces of Ukraine (2019-)  ...      Soledar   48.6969    38.0611
# 2   Military Forces of Russia (2000-)  ...      Bakhmut   48.5956    37.9999
# 3  Military Forces of Ukraine (2019-)  ...      Bakhmut   48.5956    37.9999
# 4   Military Forces of Russia (2000-)  ...  Bilohorivka   48.9259    38.2467
#
#   geo_precision                          source source_scale  \
# 0             2  Ministry of Defence of Ukraine        Other
# 1             2  Ministry of Defence of Ukraine        Other
# 2             2  Ministry of Defence of Ukraine        Other
# 3             2  Ministry of Defence of Ukraine        Other
# 4             2  Ministry of Defence of Ukraine        Other
#
#                                                notes fatalities   timestamp  \
# 0  On 13 January 2023, Russian forces, including ...          0  1673986322
# 1  On 13 January 2023, Russian forces, including ...          0  1673986322
# 2  On 13 January 2023, Russian forces shelled, as...          0  1673986322
# 3  On 13 January 2023, Russian forces shelled, as...          0  1673986322
# 4  On 13 January 2023, Russian forces shelled, as...          0  1673986322
#
#    iso3
# 0   UKR
# 1   UKR
# 2   UKR
# 3   UKR
# 4   UKR
#
# [5 rows x 28 columns]

# %%
df.event_type.value_counts()
# Out:
# Explosions/Remote violence    38724
# Battles                       12020
# Strategic developments         2413
# Violence against civilians     1364
# Protests                        304
# Riots                            12
# Name: event_type, dtype: int64

# %%
df_random_1000 = df.sample(n=1000, random_state=1000)

# %%
df_random_1000.head()
# Out:
#        data_id  iso event_id_cnty  event_id_no_cnty event_date  year  \
# 29781  9439679  804      UKR66385             66385  31-Jul-22  2022
# 15190  9579592  804      UKR76805             76805  13-Oct-22  2022
# 5197   9709984  804      UKR84173             84173   9-Dec-22  2022
# 15108  9579009  804      UKR76086             76086  13-Oct-22  2022
# 17092  9561869  804      UKR75283             75283   3-Oct-22  2022
#
#        time_precision                  event_type  \
# 29781               1  Explosions/Remote violence
# 15190               1  Explosions/Remote violence
# 5197                1  Explosions/Remote violence
# 15108               1  Explosions/Remote violence
# 17092               1                     Battles
#
#                           sub_event_type                              actor1  \
# 29781  Shelling/artillery/missile attack   Military Forces of Russia (2000-)
# 15190  Shelling/artillery/missile attack   Military Forces of Russia (2000-)
# 5197   Shelling/artillery/missile attack  Military Forces of Ukraine (2019-)
# 15108                   Air/drone strike   Military Forces of Russia (2000-)
# 17092                        Armed clash  Military Forces of Ukraine (2019-)
#
#        ...          location  latitude  longitude geo_precision  \
# 29781  ...  Iskryskivshchyna   51.2390    34.3766             2
# 15190  ...       Zolota Nyva   47.7943    36.9905             2
# 5197   ...        Pervomaisk   48.6295    38.5490             1
# 15108  ...         Bashtanka   47.4072    32.4387             2
# 17092  ...           Pobieda   47.9163    37.4631             2
#
#                                    source source_scale  \
# 29781      Ministry of Defence of Ukraine        Other
# 15190      Ministry of Defence of Ukraine        Other
# 5197   LPR People's Militia Press Service        Other
# 15108                          24 Channel     National
# 17092      Ministry of Defence of Ukraine        Other
#
#                                                    notes fatalities  \
# 29781  On 31 July 2022, Russian forces shelled near I...          0
# 15190  On 13 October 2022, Russian military forces sh...          0
# 5197   On 9 December 2022, Ukrainian forces shelled L...          0
# 15108  On 13 October 2022, Ukrainian air forces attac...          0
# 17092  On 3 October 2022, Ukrainian military forces r...          0
#
#         timestamp  iso3
# 29781  1660055882   UKR
# 15190  1666188231   UKR
# 5197   1670965353   UKR
# 15108  1666188230   UKR
# 17092  1665508789   UKR
#
# [5 rows x 28 columns]

# %% [markdown]
# Limit Data by taking a random sample of 1000 or even 5000 or 10,000 or just take about a few
# Start using less data so as not to overload
# Use Marker Clusters
# Use event type as filters
# filter by month
#
# Dashboard:
#
# 1. Side by Side bar chart
# 2. Line chart for fatalities per day and number of battles per day. Filter by month or by
# 3. Sunburst chart
#
# Filters:  1.Date     2. Number of Fatalities     3. Type of Event and type of sub_event  4. Instigator 5. News Source
#
# Map:
#
# 1. Map
#
# Info/Introduction:
#
# Group Members:
#
# Data: Table

# %%
df.columns
# Out:
# Index(['data_id', 'iso', 'event_id_cnty', 'event_id_no_cnty', 'event_date',
#        'year', 'time_precision', 'event_type', 'sub_event_type', 'actor1',
#        'assoc_actor_1', 'inter1', 'interaction', 'region', 'country', 'admin1',
#        'admin2', 'admin3', 'location', 'latitude', 'longitude',
#        'geo_precision', 'source', 'source_scale', 'notes', 'fatalities',
#        'timestamp', 'iso3'],
#       dtype='object')

# %%
df2 = df.drop(['iso', 'event_id_cnty', 'event_id_no_cnty','time_precision', 'assoc_actor_1', 'inter1', 'interaction', 'region', 'country','geo_precision', 'iso3', 'source_scale'], axis=1)

# %%
df2.columns
# Out:
# Index(['data_id', 'event_date', 'year', 'event_type', 'sub_event_type',
#        'actor1', 'admin1', 'admin2', 'admin3', 'location', 'latitude',
#        'longitude', 'source', 'notes', 'fatalities', 'timestamp'],
#       dtype='object')

# %%
df1000 = df2.sample(n=1000, random_state=1000)

# %%
df1000['source2'] = ''

# %%
df1000.index
# Out:
# Int64Index([29781, 15190,  5197, 15108, 17092,  2639, 23557, 18268, 40788,
#             45173,
#             ...
#             47225, 29635,   461,  7956, 54468, 13662, 19285, 30003, 53720,
#             47288],
#            dtype='int64', length=1000)

# %%
for indeks in df1000.index:
    srce = df1000.loc[indeks, ['source']]
    sourcevar = srce.tolist()[0]
    if sourcevar in source_list:
        df1000.loc[indeks, ['source2']] = sourcevar
    else:
        df1000.loc[indeks, ['source2']] = "other"

# %%
df1000.head()
# Out:
#        data_id event_date  year                  event_type  \
# 29781  9439679  31-Jul-22  2022  Explosions/Remote violence
# 15190  9579592  13-Oct-22  2022  Explosions/Remote violence
# 5197   9709984   9-Dec-22  2022  Explosions/Remote violence
# 15108  9579009  13-Oct-22  2022  Explosions/Remote violence
# 17092  9561869   3-Oct-22  2022                     Battles
#
#                           sub_event_type                              actor1  \
# 29781  Shelling/artillery/missile attack   Military Forces of Russia (2000-)
# 15190  Shelling/artillery/missile attack   Military Forces of Russia (2000-)
# 5197   Shelling/artillery/missile attack  Military Forces of Ukraine (2019-)
# 15108                   Air/drone strike   Military Forces of Russia (2000-)
# 17092                        Armed clash  Military Forces of Ukraine (2019-)
#
#          admin1       admin2               admin3          location  latitude  \
# 29781      Sumy      Sumskyi           Bilopilska  Iskryskivshchyna   51.2390
# 15190   Donetsk  Volnovaskyi  Velykonovosilkivska       Zolota Nyva   47.7943
# 5197    Luhansk   Alchevskyi            Kadiivska        Pervomaisk   48.6295
# 15108  Mykolaiv  Bashtanskyi           Bashtanska         Bashtanka   47.4072
# 17092   Donetsk   Pokrovskyi             Marinska           Pobieda   47.9163
#
#        longitude                              source  \
# 29781    34.3766      Ministry of Defence of Ukraine
# 15190    36.9905      Ministry of Defence of Ukraine
# 5197     38.5490  LPR People's Militia Press Service
# 15108    32.4387                          24 Channel
# 17092    37.4631      Ministry of Defence of Ukraine
#
#                                                    notes  fatalities  \
# 29781  On 31 July 2022, Russian forces shelled near I...           0
# 15190  On 13 October 2022, Russian military forces sh...           0
# 5197   On 9 December 2022, Ukrainian forces shelled L...           0
# 15108  On 13 October 2022, Ukrainian air forces attac...           0
# 17092  On 3 October 2022, Ukrainian military forces r...           0
#
#         timestamp                             source2
# 29781  1660055882      Ministry of Defence of Ukraine
# 15190  1666188231      Ministry of Defence of Ukraine
# 5197   1670965353  LPR People's Militia Press Service
# 15108  1666188230                          24 Channel
# 17092  1665508789      Ministry of Defence of Ukraine

# %%
df1000.to_json("../data/Ukraine_war_data.json", orient='records')

# %%
df1000.event_type.value_counts()
# Out:
# Explosions/Remote violence    692
# Battles                       226
# Strategic developments         50
# Violence against civilians     23
# Protests                        9
# Name: event_type, dtype: int64

# %%
df1000.groupby(['event_type', 'sub_event_type']).size()
# Out:
# event_type                  sub_event_type
# Battles                     Armed clash                            201
#                             Government regains territory            11
#                             Non-state actor overtakes territory     14
# Explosions/Remote violence  Air/drone strike                        47
#                             Remote explosive/landmine/IED           13
#                             Shelling/artillery/missile attack      632
# Protests                    Excessive force against protesters       1
#                             Peaceful protest                         8
# Strategic developments      Arrests                                  1
#                             Disrupted weapons use                   25
#                             Looting/property destruction             9
#                             Non-violent transfer of territory        7
#                             Other                                    8
# Violence against civilians  Abduction/forced disappearance           8
#                             Attack                                  14
#                             Sexual violence                          1
# dtype: int64

# %%
df1000.source2.value_counts()
# Out:
# Ministry of Defence of Ukraine           391
# other                                    156
# DPR Armed Forces Press Service           126
# 24 Channel                                87
# Institute for the Study of War            63
# Suspilne Media                            53
# Novoye Vremya Ukraine                     29
# LPR People's Militia Press Service        26
# Kharkiv Human Rights Protection Group     13
# JFO HQ press centre                       12
# Ukrinform                                 11
# 061.ua                                    11
# Liveuamap                                 11
# OSCE SMM-Ukraine                          11
# Name: source2, dtype: int64

# %%
source_list = df1000.source.value_counts().keys().tolist()[0:13]

# %% [markdown]
# data_id
# event_date
# year
# event_type
# sub_event_type
# actor1 (instigating group)
# admin1  admin2  admin3
# location latitude longitude
# source
# notes
# fatalities
# timestamp

# %% [markdown]
# markers: event_type and sub_event type   (events on the map) latitude longitude
#
# admin1 admin2 admin3  (filter by administration type)  (get geojson to make boundaries) and make graphs based on administrations
#
# fatalities: (graph)  we can try to put on the map as a heat map.
#
# pie chart for actors (who instigated)
#
# Filter by time interval time stamps and event_date and event_year
#
# Notes: You can append to marker so if someone wants to know more they can click on the marker

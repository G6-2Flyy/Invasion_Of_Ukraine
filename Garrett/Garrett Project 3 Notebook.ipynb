# %%
from splinter import Browser
from bs4 import BeautifulSoup
from webdriver_manager.chrome import ChromeDriverManager
import pandas as pd
import requests
import matplotlib.pyplot as plt

# %%
api_url = "https://api.acleddata.com/acled/read/?key=-m6oWr9ok90dWU7CT0b5&email=garrett.kidd77@gmail.com&country=ukraine&last_event_date=2022-01-01|2023-01-18&last_event_date_where=BETWEEN"
response = requests.get(api_url)
response.json()
# Out:
# {'status': 200,
#  'success': True,
#  'last_update': 49,
#  'count': 500,
#  'messages': [],
#  'data': [{'data_id': '9778529',
#    'iso': '804',
#    'event_id_cnty': 'UKR87293',
#    'event_id_no_cnty': '87293',
#    'event_date': '2023-01-13',
#    'year': '2023',
#    'time_precision': '1',
#    'event_type': 'Battles',
#    'sub_event_type': 'Armed clash',
#    'actor1': 'Military Forces of Russia (2000-)',
#    'assoc_actor_1': 'Wagner Group',
#    'inter1': '8',
#    'actor2': 'Military Forces of Ukraine (2019-)',
#    'assoc_actor_2': '',
#    'inter2': '1',
#    'interaction': '18',
#    'region': 'Europe',
#    'country': 'Ukraine',
#    'admin1': 'Donetsk',
#    'admin2': 'Bakhmutskyi',
#    'admin3': 'Soledarska',
#    'location': 'Soledar',
#    'latitude': '48.6969',
#    'longitude': '38.0611',
#    'geo_precision': '2',
#    'source': 'Ministry of Defence of Ukraine',
#    'source_scale': 'Other',
# ...

# %%
pd.set_option('display.max_columns', None)

# %%
data = "2022-01-01-2023-01-17-Europe-Ukraine.csv"
ukraine_df = pd.read_csv(data)
ukraine_df.head()
# Out:
#    data_id  iso event_id_cnty  event_id_no_cnty       event_date  year  \
# 0  9778529  804      UKR87293             87293  13 January 2023  2023
# 1  9778529  804      UKR87293             87293  13 January 2023  2023
# 2  9778632  804      UKR87396             87396  13 January 2023  2023
# 3  9778632  804      UKR87396             87396  13 January 2023  2023
# 4  9778633  804      UKR87397             87397  13 January 2023  2023
#
#    time_precision event_type sub_event_type  \
# 0               1    Battles    Armed clash
# 1               1    Battles    Armed clash
# 2               1    Battles    Armed clash
# 3               1    Battles    Armed clash
# 4               1    Battles    Armed clash
#
#                                actor1 assoc_actor_1  inter1  interaction  \
# 0   Military Forces of Russia (2000-)  Wagner Group       8           18
# 1  Military Forces of Ukraine (2019-)           NaN       1           18
# ...

# %%
ukraine_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 54837 entries, 0 to 54836
# Data columns (total 28 columns):
#  #   Column            Non-Null Count  Dtype
# ---  ------            --------------  -----
#  0   data_id           54837 non-null  int64
#  1   iso               54837 non-null  int64
#  2   event_id_cnty     54837 non-null  object
#  3   event_id_no_cnty  54837 non-null  int64
#  4   event_date        54837 non-null  object
#  5   year              54837 non-null  int64
#  6   time_precision    54837 non-null  int64
#  7   event_type        54837 non-null  object
#  8   sub_event_type    54837 non-null  object
#  9   actor1            54837 non-null  object
#  10  assoc_actor_1     7127 non-null   object
#  11  inter1            54837 non-null  int64
#  12  interaction       54837 non-null  int64
#  13  region            54837 non-null  object
#  14  country           54837 non-null  object
#  15  admin1            54821 non-null  object
# ...

# %%
clean_df1 = ukraine_df.drop(columns=['iso', 'event_id_cnty', 'event_id_no_cnty', 'time_precision', 'inter1', 'region', 'country', 'geo_precision', 'iso3'])
clean_df1.head()
# Out:
#    data_id       event_date  year event_type sub_event_type  \
# 0  9778529  13 January 2023  2023    Battles    Armed clash
# 1  9778529  13 January 2023  2023    Battles    Armed clash
# 2  9778632  13 January 2023  2023    Battles    Armed clash
# 3  9778632  13 January 2023  2023    Battles    Armed clash
# 4  9778633  13 January 2023  2023    Battles    Armed clash
#
#                                actor1 assoc_actor_1  interaction   admin1  \
# 0   Military Forces of Russia (2000-)  Wagner Group           18  Donetsk
# 1  Military Forces of Ukraine (2019-)           NaN           18  Donetsk
# 2   Military Forces of Russia (2000-)           NaN           18  Donetsk
# 3  Military Forces of Ukraine (2019-)           NaN           18  Donetsk
# 4   Military Forces of Russia (2000-)           NaN           18  Luhansk
#
#               admin2       admin3     location  latitude  longitude  \
# 0        Bakhmutskyi   Soledarska      Soledar   48.6969    38.0611
# ...

# %%
clean_df2 = clean_df1.drop(columns=['source_scale'])
clean_df2.head()
# Out:
#    data_id       event_date  year event_type sub_event_type  \
# 0  9778529  13 January 2023  2023    Battles    Armed clash
# 1  9778529  13 January 2023  2023    Battles    Armed clash
# 2  9778632  13 January 2023  2023    Battles    Armed clash
# 3  9778632  13 January 2023  2023    Battles    Armed clash
# 4  9778633  13 January 2023  2023    Battles    Armed clash
#
#                                actor1 assoc_actor_1  interaction   admin1  \
# 0   Military Forces of Russia (2000-)  Wagner Group           18  Donetsk
# 1  Military Forces of Ukraine (2019-)           NaN           18  Donetsk
# 2   Military Forces of Russia (2000-)           NaN           18  Donetsk
# 3  Military Forces of Ukraine (2019-)           NaN           18  Donetsk
# 4   Military Forces of Russia (2000-)           NaN           18  Luhansk
#
#               admin2       admin3     location  latitude  longitude  \
# 0        Bakhmutskyi   Soledarska      Soledar   48.6969    38.0611
# ...

# %%
clean_df3 = clean_df2.drop(columns=['assoc_actor_1'])
clean_df3.head()
# Out:
#    data_id       event_date  year event_type sub_event_type  \
# 0  9778529  13 January 2023  2023    Battles    Armed clash
# 1  9778529  13 January 2023  2023    Battles    Armed clash
# 2  9778632  13 January 2023  2023    Battles    Armed clash
# 3  9778632  13 January 2023  2023    Battles    Armed clash
# 4  9778633  13 January 2023  2023    Battles    Armed clash
#
#                                actor1  interaction   admin1  \
# 0   Military Forces of Russia (2000-)           18  Donetsk
# 1  Military Forces of Ukraine (2019-)           18  Donetsk
# 2   Military Forces of Russia (2000-)           18  Donetsk
# 3  Military Forces of Ukraine (2019-)           18  Donetsk
# 4   Military Forces of Russia (2000-)           18  Luhansk
#
#               admin2       admin3     location  latitude  longitude  \
# 0        Bakhmutskyi   Soledarska      Soledar   48.6969    38.0611
# 1        Bakhmutskyi   Soledarska      Soledar   48.6969    38.0611
# ...

# %%
clean_df3.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 54837 entries, 0 to 54836
# Data columns (total 17 columns):
#  #   Column          Non-Null Count  Dtype
# ---  ------          --------------  -----
#  0   data_id         54837 non-null  int64
#  1   event_date      54837 non-null  object
#  2   year            54837 non-null  int64
#  3   event_type      54837 non-null  object
#  4   sub_event_type  54837 non-null  object
#  5   actor1          54837 non-null  object
#  6   interaction     54837 non-null  int64
#  7   admin1          54821 non-null  object
#  8   admin2          54739 non-null  object
#  9   admin3          54357 non-null  object
#  10  location        54837 non-null  object
#  11  latitude        54837 non-null  float64
#  12  longitude       54837 non-null  float64
#  13  source          54837 non-null  object
#  14  notes           54837 non-null  object
#  15  fatalities      54837 non-null  int64
#  16  timestamp       54837 non-null  int64
# ...
